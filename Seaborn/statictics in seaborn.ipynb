# %% [markdown]
# # Statictics

# %%
from IPython.display import Image
Image('T:\\images for linkedlin\\sts.jpg',width = 300,height = 400)

# %% [markdown]
# - is the place where maths can be applied  to understand the data
# types
# descriptive statictics - graphical Representation of data
# inferential statictics - using statictics technique and sample data we are going to understand the population data

# %% [markdown]
# # Types of Data

# %%
a = pd.read_csv("T:\\python\\class\\Titanic-Dataset.csv")
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
numeric_data = a.select_dtypes(exclude = 'object')
numeric_data
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
cat_data = a.select_dtypes(include = 'object')
cat_data
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %% [markdown]
# IN DATA

# %% [raw]
# rows = obbservations
# columns = features
# unique value = labels

# %%
import numpy as np

# %%
import pandas as pd

# %%
a = pd.DataFrame({'things':['pen','pencil','pen','pencil']})
a
# Out:
#    things
# 0     pen
# 1  pencil
# 2     pen
# 3  pencil

# %%
a['things'].unique()
# Out:
# array(['pen', 'pencil'], dtype=object)

# %% [raw]
# here
# rows - observation
# columns - feature
# unique values - labels

# %% [markdown]
# # Types of Data

# %%
d_type = pd.DataFrame({'credit_cards':['bob','indian','hdfc','yesbank'],'weight':[23.4,34.1,44.1,56.0],'gender':['male','female','unisex','all_kind'],'university':['chairman','principle','HOD','teacher']})
d_type
# Out:
#   credit_cards  weight    gender university
# 0          bob    23.4      male   chairman
# 1       indian    34.1    female  principle
# 2         hdfc    44.1    unisex        HOD
# 3      yesbank    56.0  all_kind    teacher

# %% [markdown]
# # Measure of Central Tendency

# %% [markdown]
# its get acurrate description of entire data

# %% [markdown]
# mean

# %%
ct = pd.DataFrame({'values':[2,4,5,6,7,11,124,8]})
ct
# Out:
#    values
# 0       2
# 1       4
# 2       5
# 3       6
# 4       7
# 5      11
# 6     124
# 7       8

# %%
ct['values'].mean()
# Out:
# 20.875

# %% [markdown]
# odd mean

# %% [markdown]
# Median

# %% [markdown]
# even mean - first sort it middle take 2 values then add it and divide by 2

# %%
c = pd.DataFrame({'values':[2,4,5,6,7,11,124,8]})
c
# Out:
#    values
# 0       2
# 1       4
# 2       5
# 3       6
# 4       7
# 5      11
# 6     124
# 7       8

# %%
c['values'].median()
# Out:
# 6.5

# %% [markdown]
# odd median - sort it and take middle value

# %%
ct = pd.DataFrame({'values':[2,4,5,6,7,11,124]})
ct
# Out:
#    values
# 0       2
# 1       4
# 2       5
# 3       6
# 4       7
# 5      11
# 6     124

# %%
ct['values'].median()
# Out:
# 6.0

# %% [markdown]
# Mode -repeated values

# %%
cts = pd.DataFrame({'values':[2,4,5,6,7,11,124,7]})
cts
# Out:
#    values
# 0       2
# 1       4
# 2       5
# 3       6
# 4       7
# 5      11
# 6     124
# 7       7

# %%
cts['values'].mode()
# Out:
# 0    7
# Name: values, dtype: int64

# %%
cts['values'].mode()[0]
# Out:
# 7

# %% [markdown]
# # Measure of Dispersion

# %% [markdown]
# Range

# %% [markdown]
# range = hightest value - lowest value

# %% [markdown]
# # percentile

# %%
a = pd.read_csv("T:\\python\\class\\Titanic-Dataset.csv")
a
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
a.shape
# Out:
# (891, 12)

# %%
a['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
pds = pd.DataFrame(np.abs(a['Age']))
d = pds.quantile(300/891)
                 
print("percentage score",d)
# Out:
# percentage score Age    23.0
# Name: 0.3367003367003367, dtype: float64

# %% [markdown]
# # Qutliers

# %% [markdown]
# - is a pieces od data

# %%
import seaborn as sns

# %%
d = pd.read_csv("T:\\python\\class\\Titanic-Dataset.csv")
d
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.boxplot(x=d['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=d['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %% [markdown]
# # Variance

# %% [markdown]
# It has arithmetric distance from the mean and remaining data

# %% [markdown]
# # Standard Deviation

# %% [markdown]
# it is easy to find the lying data between the data points by using mean

# %%
titanic = pd.read_csv("T:\\python\\class\\Titanic-Dataset.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic['Age'].std()
# Out:
# 14.526497332334044

# %% [markdown]
# to check graphical representation using displot

# %%
sns.displot(x = titanic['Age'])

# %%
sns.displot(x = titanic['Age'],kind = 'kde')

# %% [markdown]
# # correlation

# %% [markdown]
# correlation can be done by heatmap

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = titanic[['Age','Fare']]
df
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df.corr(method = 'pearson')
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %%
sns.heatmap(data=df.corr(method='pearson'),vmin=-1,vmax=1,annot=True,cmap ='crest')
# Out:
# <Axes: >

# %%
sns.heatmap(data=df.corr(method='spearman'),vmin=-1,vmax=1,annot=True,cmap ='crest')
# Out:
# <Axes: >

# %%
sns.heatmap(numeric.corr(method='spearman'),vmin=-1,vmax =1,annot =True,cmap ='crest')
# Out:
# <Axes: >

# %% [markdown]
#  # Multivariant

# %%
numeric = titanic.select_dtypes(exclude = 'object')
numeric
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.pairplot(data = numeric)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
