# %%
import pandas as pd

# %%
import numpy as np

# %%
av_gers = pd.read_csv("T:\\python\\class\\IPL_2023-22_Sold_Players.csv")
av_gers
# Out:
#      Season               Name Nationality          Type  \
# 0      2023    Ajinkya Rahane      Indian        Batter
# 1      2023     Bhagath Varma      Indian   All-Rounder
# 2      2023     Kyle Jamieson    Overseas        Bowler
# 3      2023       Ajay Mandal      Indian   All-Rounder
# 4      2023    Nishant Sindhu      Indian   All-Rounder
# ..      ...                ...         ...           ...
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team         Price
# 0     Chennai Super Kings    50,00,000
# 1     Chennai Super Kings    20,00,000
# 2     Chennai Super Kings  1,00,00,000
# 3     Chennai Super Kings    20,00,000
# 4     Chennai Super Kings    60,00,000
# ..                    ...           ...
# ...

# %%
av_gers.head()
# Out:
#    Season             Name Nationality          Type                  Team  \
# 0    2023  Ajinkya Rahane      Indian        Batter    Chennai Super Kings
# 1    2023   Bhagath Varma      Indian   All-Rounder    Chennai Super Kings
# 2    2023   Kyle Jamieson    Overseas        Bowler    Chennai Super Kings
# 3    2023     Ajay Mandal      Indian   All-Rounder    Chennai Super Kings
# 4    2023  Nishant Sindhu      Indian   All-Rounder    Chennai Super Kings
#
#           Price
# 0    50,00,000
# 1    20,00,000
# 2  1,00,00,000
# 3    20,00,000
# 4    60,00,000

# %%
av_gers.tail()
# Out:
#      Season               Name Nationality          Type  \
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team         Price
# 279   Sunrisers Hyderabad    50,00,000
# 280   Sunrisers Hyderabad  2,40,00,000
# 281   Sunrisers Hyderabad    20,00,000
# 282   Sunrisers Hyderabad    20,00,000
# 283   Sunrisers Hyderabad    20,00,000

# %%
av_gers.shape
# Out:
# (284, 6)

# %%
av_gers.size
# Out:
# 1704

# %%
len(av_gers)
# Out:
# 284

# %%
av_gers.columns
# Out:
# Index(['Season', 'Name', 'Nationality', 'Type', 'Team', 'Price'], dtype='object')

# %%
av_gers.isnull()
# Out:
#      Season   Name  Nationality   Type   Team  Price
# 0     False  False        False  False  False  False
# 1     False  False        False  False  False  False
# 2     False  False        False  False  False  False
# 3     False  False        False  False  False  False
# 4     False  False        False  False  False  False
# ..      ...    ...          ...    ...    ...    ...
# 279   False  False        False  False  False  False
# 280   False  False        False  False  False  False
# 281   False  False        False  False  False  False
# 282   False  False        False  False  False  False
# 283   False  False        False  False  False  False
#
# [284 rows x 6 columns]

# %%
av_gers.isnull().sum() # no null values
# Out:
# Season         0
# Name           0
# Nationality    0
# Type           0
# Team           0
# Price          0
# dtype: int64

# %% [markdown]
# # rename

# %%
av_gers=av_gers.rename(columns={'Type':'variant'})
av_gers
# Out:
#      Season               Name Nationality       variant  \
# 0      2023    Ajinkya Rahane      Indian        Batter
# 1      2023     Bhagath Varma      Indian   All-Rounder
# 2      2023     Kyle Jamieson    Overseas        Bowler
# 3      2023       Ajay Mandal      Indian   All-Rounder
# 4      2023    Nishant Sindhu      Indian   All-Rounder
# ..      ...                ...         ...           ...
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team         Price
# 0     Chennai Super Kings    50,00,000
# 1     Chennai Super Kings    20,00,000
# 2     Chennai Super Kings  1,00,00,000
# 3     Chennai Super Kings    20,00,000
# 4     Chennai Super Kings    60,00,000
# ..                    ...           ...
# ...

# %%
av_gers = av_gers.rename(columns={'Price':'Money_price'})
av_gers
# Out:
#      Season               Name Nationality       variant  \
# 0      2023    Ajinkya Rahane      Indian        Batter
# 1      2023     Bhagath Varma      Indian   All-Rounder
# 2      2023     Kyle Jamieson    Overseas        Bowler
# 3      2023       Ajay Mandal      Indian   All-Rounder
# 4      2023    Nishant Sindhu      Indian   All-Rounder
# ..      ...                ...         ...           ...
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team   Money_price
# 0     Chennai Super Kings    50,00,000
# 1     Chennai Super Kings    20,00,000
# 2     Chennai Super Kings  1,00,00,000
# 3     Chennai Super Kings    20,00,000
# 4     Chennai Super Kings    60,00,000
# ..                    ...           ...
# ...

# %% [markdown]
# # Sorting

# %%
av_gers.sort_values(by = 'Name',ascending = True)
# Out:
#      Season                  Name Nationality       variant  \
# 53     2023            Abdul P A      Indian   All-Rounder
# 157    2022       Abhijeet Tomar      Indian       Batsman
# 127    2022  Abhinav Sadarangani      Indian       Batsman
# 270    2022      Abhishek Sharma      Indian   All-Rounder
# 96     2022           Adam Milne    Overseas        Bowler
# ..      ...                   ...         ...           ...
# 135    2022          Yash  Dayal      Indian        Bowler
# 114    2022           Yash Dhull      Indian   All-Rounder
# 34     2023          Yash Thakur      Indian        Bowler
# 32     2023       Yudhvir Charak      Indian   All-Rounder
# 229    2022     Yuzvendra Chahal      Indian        Bowler
#
#                        Team   Money_price
# 53         Rajasthan Royals    20,00,000
# 157   Kolkata Knight Riders    40,00,000
# 127          Gujarat Titans  2,60,00,000
# 270     Sunrisers Hyderabad  6,50,00,000
# 96      Chennai Super Kings  1,90,00,000
# ...

# %%
av_gers['Nationality'].unique()
# Out:
# array(['Indian ', 'Overseas '], dtype=object)

# %%
av_gers.value_counts('variant')
# Out:
# variant
# All-Rounder       106
# Bowler             96
# Batsman            36
# Wicket Keeper      22
# Batter             12
# Wicket-Keeper      12
# dtype: int64

# %%
av_gers=av_gers.drop(['Season'],axis = 1)

# %%
av_gers.head()
# Out:
#               Name Nationality          Type                  Team  \
# 0  Ajinkya Rahane      Indian        Batter    Chennai Super Kings
# 1   Bhagath Varma      Indian   All-Rounder    Chennai Super Kings
# 2   Kyle Jamieson    Overseas        Bowler    Chennai Super Kings
# 3     Ajay Mandal      Indian   All-Rounder    Chennai Super Kings
# 4  Nishant Sindhu      Indian   All-Rounder    Chennai Super Kings
#
#           Price
# 0    50,00,000
# 1    20,00,000
# 2  1,00,00,000
# 3    20,00,000
# 4    60,00,000

# %%
x = av_gers.iloc[:,:-1]
x
# Out:
#                   Name Nationality          Type                  Team
# 0      Ajinkya Rahane      Indian        Batter    Chennai Super Kings
# 1       Bhagath Varma      Indian   All-Rounder    Chennai Super Kings
# 2       Kyle Jamieson    Overseas        Bowler    Chennai Super Kings
# 3         Ajay Mandal      Indian   All-Rounder    Chennai Super Kings
# 4      Nishant Sindhu      Indian   All-Rounder    Chennai Super Kings
# ..                 ...         ...           ...                   ...
# 279  Fazalhaq Farooqi    Overseas        Bowler    Sunrisers Hyderabad
# 280       Sean Abbott    Overseas        Bowler    Sunrisers Hyderabad
# 281         R Samarth      Indian       Batsman    Sunrisers Hyderabad
# 282    Shashank Singh      Indian   All-Rounder    Sunrisers Hyderabad
# 283     Saurabh Dubey      Indian        Bowler    Sunrisers Hyderabad
#
# [284 rows x 4 columns]

# %%
y = av_gers.iloc[:,-1]
y
# Out:
# 0        50,00,000
# 1        20,00,000
# 2      1,00,00,000
# 3        20,00,000
# 4        60,00,000
#            ...
# 279      50,00,000
# 280    2,40,00,000
# 281      20,00,000
# 282      20,00,000
# 283      20,00,000
# Name: Price, Length: 284, dtype: object

# %%
av_gers.describe()
# Out:
#                    Name Nationality          Type                  Team  \
# count               284         284           284                   284
# unique              266           2             6                    10
# top     Ajinkya Rahane      Indian   All-Rounder    Sunrisers Hyderabad
# freq                  2         188           106                    33
#
#              Price
# count          284
# unique          66
# top     20,00,000
# freq            80

# %%
av_gers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         284 non-null    object
#  1   Nationality  284 non-null    object
#  2   Type         284 non-null    object
#  3   Team         284 non-null    object
#  4   Price        284 non-null    object
# dtypes: object(5)
# memory usage: 11.2+ KB

# %%
values = []
for i in range(284):
    values.append(i)

# %%
new_col = pd.DataFrame(values)
new_col
# Out:
#        0
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ..   ...
# 279  279
# 280  280
# 281  281
# 282  282
# 283  283
#
# [284 rows x 1 columns]

# %%
av_gers = pd.concat([av_gers,new_col],axis =1)
av_gers
# Out:
#                   Name Nationality          Type                  Team  \
# 0      Ajinkya Rahane      Indian        Batter    Chennai Super Kings
# 1       Bhagath Varma      Indian   All-Rounder    Chennai Super Kings
# 2       Kyle Jamieson    Overseas        Bowler    Chennai Super Kings
# 3         Ajay Mandal      Indian   All-Rounder    Chennai Super Kings
# 4      Nishant Sindhu      Indian   All-Rounder    Chennai Super Kings
# ..                 ...         ...           ...                   ...
# 279  Fazalhaq Farooqi    Overseas        Bowler    Sunrisers Hyderabad
# 280       Sean Abbott    Overseas        Bowler    Sunrisers Hyderabad
# 281         R Samarth      Indian       Batsman    Sunrisers Hyderabad
# 282    Shashank Singh      Indian   All-Rounder    Sunrisers Hyderabad
# 283     Saurabh Dubey      Indian        Bowler    Sunrisers Hyderabad
#
#             Price            0    0
# 0      50,00,000          Name    0
# 1      20,00,000   Nationality    1
# ...
